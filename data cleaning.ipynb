# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("D:\ml Projects\mi_data.csv")

# %%
df.head()
# Out:
#                               model_names  ratings    price  \
# 0  REDMI 10 Power (Sporty Orange, 128 GB)      4.2  ₹13,500
# 1    REDMI 10 Power (Power Black, 128 GB)      4.2  ₹12,840
# 2   Redmi 9A Sport (Metallic Blue, 32 GB)      4.1   ₹7,520
# 3     Redmi 9A Sport (Coral Green, 32 GB)      4.2   ₹8,450
# 4  Xiaomi 11Lite NE (Vinyl Black, 128 GB)      4.2  ₹21,644
#
#                                               imgURL  \
# 0  https://rukminim2.flixcart.com/image/312/312/x...
# 1  https://rukminim2.flixcart.com/image/312/312/x...
# 2  https://rukminim2.flixcart.com/image/312/312/x...
# 3  https://rukminim2.flixcart.com/image/312/312/x...
# 4  https://rukminim2.flixcart.com/image/312/312/x...
#
#                                          storage_ram  \
# 0  Internal Storage128 GBRAM8 GBMemory Card Slot ...
# 1  Internal Storage128 GBRAM8 GBMemory Card Slot ...
# 2  Internal Storage32 GBRAM2 GBMemory Card Slot T...
# 3  Internal Storage32 GBRAM3 GBMemory Card Slot T...
# ...

# %%
df.shape
# Out:
# (548, 8)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 548 entries, 0 to 547
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   model_names   548 non-null    object
#  1   ratings       548 non-null    float64
#  2   price         548 non-null    object
#  3   imgURL        548 non-null    object
#  4   storage_ram   548 non-null    object
#  5   os_processor  548 non-null    object
#  6   network       548 non-null    object
#  7   battery       548 non-null    object
# dtypes: float64(1), object(7)
# memory usage: 34.4+ KB

# %%
df.storage_ram
# Out:
# 0      Internal Storage128 GBRAM8 GBMemory Card Slot ...
# 1      Internal Storage128 GBRAM8 GBMemory Card Slot ...
# 2      Internal Storage32 GBRAM2 GBMemory Card Slot T...
# 3      Internal Storage32 GBRAM3 GBMemory Card Slot T...
# 4      Internal Storage128 GBRAM6 GBExpandable Storag...
#                              ...
# 543    Internal Storage32 GBRAM3 GBExpandable Storage...
# 544    Internal Storage32 GBRAM3 GBMemory Card Slot T...
# 545                        Internal Storage128 GBRAM6 GB
# 546    Internal Storage64 GBRAM4 GBExpandable Storage...
# 547    Internal Storage64 GBRAM4 GBExpandable Storage...
# Name: storage_ram, Length: 548, dtype: object

# %%
# Data Cleaning

# %%
df.isnull().sum()
# no null values
# Out:
# model_names     0
# ratings         0
# price           0
# imgURL          0
# storage_ram     0
# os_processor    0
# network         0
# battery         0
# dtype: int64

# %%
# -->splitting the columns and cleaning the data

# %%
df.drop(["imgURL"],axis='columns',inplace=True)

# %%
def split_dat(x):
    currency_symbol,value=x.split("₹")
    value=int(value)
    return value

# %%
df["price"]=df["price"].apply(lambda x:int(x.split("₹")[1].replace(",","")))

# %%
df.head()
# Out:
#                               model_names  ratings  price  \
# 0  REDMI 10 Power (Sporty Orange, 128 GB)      4.2  13500
# 1    REDMI 10 Power (Power Black, 128 GB)      4.2  12840
# 2   Redmi 9A Sport (Metallic Blue, 32 GB)      4.1   7520
# 3     Redmi 9A Sport (Coral Green, 32 GB)      4.2   8450
# 4  Xiaomi 11Lite NE (Vinyl Black, 128 GB)      4.2  21644
#
#                                          storage_ram  \
# 0  Internal Storage128 GBRAM8 GBMemory Card Slot ...
# 1  Internal Storage128 GBRAM8 GBMemory Card Slot ...
# 2  Internal Storage32 GBRAM2 GBMemory Card Slot T...
# 3  Internal Storage32 GBRAM3 GBMemory Card Slot T...
# 4  Internal Storage128 GBRAM6 GBExpandable Storag...
#
#                                         os_processor  \
# 0  Operating SystemAndroid 13Processor CoreOcta C...
# 1  Operating SystemAndroid 13Processor CoreOcta C...
# 2  Operating SystemAndroid Q 10Processor CoreOcta...
# 3  Operating SystemAndroid Q 10Processor CoreOcta...
# ...

# %%
df.head()
# Out:
#                               model_names  ratings  price  \
# 0  REDMI 10 Power (Sporty Orange, 128 GB)      4.2  13500
# 1    REDMI 10 Power (Power Black, 128 GB)      4.2  12840
# 2   Redmi 9A Sport (Metallic Blue, 32 GB)      4.1   7520
# 3     Redmi 9A Sport (Coral Green, 32 GB)      4.2   8450
# 4  Xiaomi 11Lite NE (Vinyl Black, 128 GB)      4.2  21644
#
#                                          storage_ram  \
# 0  Internal Storage128 GBRAM8 GBMemory Card Slot ...
# 1  Internal Storage128 GBRAM8 GBMemory Card Slot ...
# 2  Internal Storage32 GBRAM2 GBMemory Card Slot T...
# 3  Internal Storage32 GBRAM3 GBMemory Card Slot T...
# 4  Internal Storage128 GBRAM6 GBExpandable Storag...
#
#                                         os_processor  \
# 0  Operating SystemAndroid 13Processor CoreOcta C...
# 1  Operating SystemAndroid 13Processor CoreOcta C...
# 2  Operating SystemAndroid Q 10Processor CoreOcta...
# 3  Operating SystemAndroid Q 10Processor CoreOcta...
# ...

# %%
df["battery"]=df["battery"].apply(lambda x:(x.split("ity")[1]))

# %%
df["battery"]=df["battery"].apply(lambda x:int(x.split(" ")[0]))

# %%
df.head()
# Out:
#                               model_names  ratings  price  \
# 0  REDMI 10 Power (Sporty Orange, 128 GB)      4.2  13500
# 1    REDMI 10 Power (Power Black, 128 GB)      4.2  12840
# 2   Redmi 9A Sport (Metallic Blue, 32 GB)      4.1   7520
# 3     Redmi 9A Sport (Coral Green, 32 GB)      4.2   8450
# 4  Xiaomi 11Lite NE (Vinyl Black, 128 GB)      4.2  21644
#
#                                          storage_ram  \
# 0  Internal Storage128 GBRAM8 GBMemory Card Slot ...
# 1  Internal Storage128 GBRAM8 GBMemory Card Slot ...
# 2  Internal Storage32 GBRAM2 GBMemory Card Slot T...
# 3  Internal Storage32 GBRAM3 GBMemory Card Slot T...
# 4  Internal Storage128 GBRAM6 GBExpandable Storag...
#
#                                         os_processor  \
# 0  Operating SystemAndroid 13Processor CoreOcta C...
# 1  Operating SystemAndroid 13Processor CoreOcta C...
# 2  Operating SystemAndroid Q 10Processor CoreOcta...
# 3  Operating SystemAndroid Q 10Processor CoreOcta...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 548 entries, 0 to 547
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   model_names   548 non-null    object
#  1   ratings       548 non-null    float64
#  2   price         548 non-null    int64
#  3   storage_ram   548 non-null    object
#  4   os_processor  548 non-null    object
#  5   network       548 non-null    object
#  6   battery       548 non-null    int64
# dtypes: float64(1), int64(2), object(4)
# memory usage: 30.1+ KB

# %%
df["network"]=df["network"].apply(lambda x:int(x.split("Type")[1].split("G")[0]))

# %%
df.head()
# Out:
#                               model_names  ratings  price  \
# 0  REDMI 10 Power (Sporty Orange, 128 GB)      4.2  13500
# 1    REDMI 10 Power (Power Black, 128 GB)      4.2  12840
# 2   Redmi 9A Sport (Metallic Blue, 32 GB)      4.1   7520
# 3     Redmi 9A Sport (Coral Green, 32 GB)      4.2   8450
# 4  Xiaomi 11Lite NE (Vinyl Black, 128 GB)      4.2  21644
#
#                                          storage_ram  \
# 0  Internal Storage128 GBRAM8 GBMemory Card Slot ...
# 1  Internal Storage128 GBRAM8 GBMemory Card Slot ...
# 2  Internal Storage32 GBRAM2 GBMemory Card Slot T...
# 3  Internal Storage32 GBRAM3 GBMemory Card Slot T...
# 4  Internal Storage128 GBRAM6 GBExpandable Storag...
#
#                                         os_processor  network  battery
# 0  Operating SystemAndroid 13Processor CoreOcta C...        4     6000
# 1  Operating SystemAndroid 13Processor CoreOcta C...        4     6000
# 2  Operating SystemAndroid Q 10Processor CoreOcta...        4     5000
# ...

# %%
df.network.value_counts()
# Out:
# 4    237
# 5    150
# 3    146
# 2     15
# Name: network, dtype: int64

# %%
df.head()
# Out:
#                               model_names  ratings  price  \
# 0  REDMI 10 Power (Sporty Orange, 128 GB)      4.2  13500
# 1    REDMI 10 Power (Power Black, 128 GB)      4.2  12840
# 2   Redmi 9A Sport (Metallic Blue, 32 GB)      4.1   7520
# 3     Redmi 9A Sport (Coral Green, 32 GB)      4.2   8450
# 4  Xiaomi 11Lite NE (Vinyl Black, 128 GB)      4.2  21644
#
#                                          storage_ram  \
# 0  Internal Storage128 GBRAM8 GBMemory Card Slot ...
# 1  Internal Storage128 GBRAM8 GBMemory Card Slot ...
# 2  Internal Storage32 GBRAM2 GBMemory Card Slot T...
# 3  Internal Storage32 GBRAM3 GBMemory Card Slot T...
# 4  Internal Storage128 GBRAM6 GBExpandable Storag...
#
#                                         os_processor  network  battery
# 0  Operating SystemAndroid 13Processor CoreOcta C...        4     6000
# 1  Operating SystemAndroid 13Processor CoreOcta C...        4     6000
# 2  Operating SystemAndroid Q 10Processor CoreOcta...        4     5000
# ...
